# %%
# Importando as bibliotecas que vamos usar
import pandas as pd
# Out:
# c:\Users\renan\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
caminho = r'C:\Users\renan\OneDrive\Documentos\Python Scripts\AquivosAnalise\Mobile Price.csv'


tbl_mob = pd.read_csv(caminho,sep=';')


tbl_json = tbl_mob.to_json('mobile.json',orient='records',index=False)

# %%
print(type(tbl_json))
tbl_json = pd.read_json('mobile.json')
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
tbl_json = tbl_json.iloc[0:,0:]
tbl_json
# Out:
#       bluetooth  clock-speed  dual-sim  front-camera-pixels  four-g  \
# 0             0          2.2         0                    1       0
# 1             1          0.5         1                    0       1
# 2             1          0.5         1                    2       1
# 3             1          2.5         0                    0       0
# 4             1          1.2         0                   13       1
# ...         ...          ...       ...                  ...     ...
# 1995          1          0.5         1                    0       1
# 1996          1          2.6         1                    0       0
# 1997          0          0.9         1                    1       1
# 1998          0          0.9         0                    4       1
# 1999          1          2.0         1                    5       1
#
#       internal-memory  mobile-depth  mobile-weight  processor-cores-number  \
# ...
