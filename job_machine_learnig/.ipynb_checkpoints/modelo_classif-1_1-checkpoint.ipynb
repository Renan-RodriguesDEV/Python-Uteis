# %% [markdown]
# # Modelo para dois diretorios train e validation

# %%
import os
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Rescaling
import numpy as np

# Carregando as configurações
data_base_path = 'C:/Users/User/Downloads/Imagens'  # Diretório da base de dados
dir_train = os.path.join(data_base_path, 'train').replace(os.path.sep, '/')  # Diretório de treinamento
dir_validation = os.path.join(data_base_path, 'validation').replace(os.path.sep, '/')  # Diretório de validação

# Definindo parâmetros
batch_size = 32  # Tamanho do lote
img_width, img_height = 180, 180  # Largura e altura das imagens
img_size = (img_width, img_height)  # Tamanho das imagens
epochs = 20  # Número de épocas de treinamento
learning_rate = 0.0001  # Taxa de aprendizagem

# Separando os conjuntos de dados
train_ds = tf.keras.utils.image_dataset_from_directory(
    dir_train,
    shuffle=True,
    image_size=img_size,
    batch_size=batch_size,
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    dir_validation,
    shuffle=True,
    image_size=img_size,
    batch_size=batch_size,
)

# Obtendo os nomes das classes
nomes_classes = train_ds.class_names
num_classes = len(nomes_classes)  # Número de classes

# Separando um conjunto de teste do conjunto de validação
val_ds_card = tf.data.experimental.cardinality(val_ds)
lotes_val_ds = val_ds_card // 3 # Número de lotes para teste

test_ds = val_ds.take(lotes_val_ds)  # Conjunto de teste
val_ds = val_ds.skip(lotes_val_ds)  # Conjunto de validação ajustado

# Exibindo informações sobre os conjuntos de dados
print('Cardinalidade do Conjunto de Validação:', tf.data.experimental.cardinality(val_ds))
print('Cardinalidade do Conjunto de Teste:', tf.data.experimental.cardinality(test_ds))
# Out:
# Found 34 files belonging to 3 classes.
# Found 16 files belonging to 3 classes.
# Cardinalidade do Conjunto de Validação: tf.Tensor(1, shape=(), dtype=int64)
# Cardinalidade do Conjunto de Teste: tf.Tensor(0, shape=(), dtype=int64)

# %%
# Configurando o desempenho automático
AUTOTUNE = tf.data.AUTOTUNE

# Pré-processamento dos conjuntos de dados
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Normalização das imagens
shape = (img_width, img_height, 3)  # Forma das imagens normalizadas

# %%
# Criando o modelo de rede neural
model = tf.keras.Sequential([
    # data_augmentation,  # Adicionando Data Augmentation
    Rescaling(1./255,input_shape=shape),
    Conv2D(16, (3, 3), padding='same',activation='relu'),  # Menor número de filtros
    MaxPooling2D(),
    Dropout(0.5),
    Conv2D(32, (3, 3), padding='same',activation='relu'),  # Menor número de filtros
    MaxPooling2D(),
    Dropout(0.5),
    Flatten(),
    Dense(64, activation='relu'),  # Menor número de unidades
    Dropout(0.5),
    Dense(num_classes, activation='softmax'),
])


# Compilando o modelo
model.compile(
    optimizer='adam',  # Otimizador Adam
    loss='sparse_categorical_crossentropy',  # Perda categórica cruzada esparsa (multi-classe)
    metrics=['accuracy'],  # Métricas a serem monitoradas (precisão)
)

# Resumo do modelo
model.summary()
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:18: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 180, 180, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 90, 90, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 90, 90, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 90, 90, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 45, 45, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 45, 45, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     4,147,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,152,547 (15.84 MB)
#  Trainable params: 4,152,547 (15.84 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import *

# Callbacks
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

checkpoint_callback = ModelCheckpoint(
    filepath='best_model.keras',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    mode='min',
    verbose=1
)


history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[reduce_lr, early_stopping, checkpoint_callback]
)
# Out:
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.4706 - loss: 1.7789
# Epoch 1: val_loss improved from inf to 1.90850, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.4608 - loss: 1.9911 - val_accuracy: 0.2500 - val_loss: 1.9085 - learning_rate: 0.0010
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3640 - loss: 6.2203
# Epoch 2: val_loss improved from 1.90850 to 1.85116, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 413ms/step - accuracy: 0.3603 - loss: 6.2283 - val_accuracy: 0.4375 - val_loss: 1.8512 - learning_rate: 0.0010
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.1471 - loss: 6.5173
# Epoch 3: val_loss improved from 1.85116 to 1.40887, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step - accuracy: 0.1961 - loss: 7.1751 - val_accuracy: 0.4375 - val_loss: 1.4089 - learning_rate: 0.0010
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.4559 - loss: 3.3162
# Epoch 4: val_loss improved from 1.40887 to 1.10517, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step - accuracy: 0.4412 - loss: 3.5898 - val_accuracy: 0.4375 - val_loss: 1.1052 - learning_rate: 0.0010
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3787 - loss: 3.4943
# Epoch 5: val_loss improved from 1.10517 to 1.10093, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 414ms/step - accuracy: 0.3799 - loss: 3.4999 - val_accuracy: 0.3125 - val_loss: 1.1009 - learning_rate: 0.0010
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4697 - loss: 1.5249
# Epoch 6: val_loss did not improve from 1.10093
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.4700 - loss: 1.5296 - val_accuracy: 0.2500 - val_loss: 1.1096 - learning_rate: 0.0010
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4246 - loss: 1.7382
# Epoch 7: val_loss did not improve from 1.10093
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.4203 - loss: 1.7424 - val_accuracy: 0.1875 - val_loss: 1.1048 - learning_rate: 0.0010
# Epoch 8/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.3640 - loss: 1.4015
# Epoch 8: val_loss did not improve from 1.10093
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.3603 - loss: 1.4011 - val_accuracy: 0.3125 - val_loss: 1.1011 - learning_rate: 0.0010
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.3787 - loss: 1.2256
# Epoch 9: val_loss improved from 1.10093 to 1.09945, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 443ms/step - accuracy: 0.3799 - loss: 1.2279 - val_accuracy: 0.3125 - val_loss: 1.0995 - learning_rate: 0.0010
# Epoch 10/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.8088 - loss: 0.9372
# Epoch 10: val_loss improved from 1.09945 to 1.09871, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step - accuracy: 0.7451 - loss: 0.9733 - val_accuracy: 0.3125 - val_loss: 1.0987 - learning_rate: 0.0010
# Epoch 11/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4237 - loss: 1.0992
# Epoch 11: val_loss improved from 1.09871 to 1.09812, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 441ms/step - accuracy: 0.4295 - loss: 1.0975 - val_accuracy: 0.3125 - val_loss: 1.0981 - learning_rate: 0.0010
# Epoch 12/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.7206 - loss: 0.9697
# Epoch 12: val_loss improved from 1.09812 to 1.09765, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step - accuracy: 0.6275 - loss: 1.0109 - val_accuracy: 0.3125 - val_loss: 1.0977 - learning_rate: 0.0010
# Epoch 13/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4540 - loss: 1.0624
# Epoch 13: val_loss improved from 1.09765 to 1.09720, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 0.4596 - loss: 1.0607 - val_accuracy: 0.3750 - val_loss: 1.0972 - learning_rate: 0.0010
# Epoch 14/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5450 - loss: 1.0343
# Epoch 14: val_loss improved from 1.09720 to 1.09637, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 419ms/step - accuracy: 0.5496 - loss: 1.0325 - val_accuracy: 0.4375 - val_loss: 1.0964 - learning_rate: 0.0010
# Epoch 15/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.4237 - loss: 1.0696
# Epoch 15: val_loss improved from 1.09637 to 1.09548, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 480ms/step - accuracy: 0.4295 - loss: 1.0675 - val_accuracy: 0.4375 - val_loss: 1.0955 - learning_rate: 0.0010
# Epoch 16/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.7353 - loss: 0.8628
# Epoch 16: val_loss improved from 1.09548 to 1.09515, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step - accuracy: 0.6471 - loss: 0.9252 - val_accuracy: 0.4375 - val_loss: 1.0952 - learning_rate: 0.0010
# Epoch 17/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4393 - loss: 1.1304
# Epoch 17: val_loss did not improve from 1.09515
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4400 - loss: 1.1281 - val_accuracy: 0.4375 - val_loss: 1.0961 - learning_rate: 0.0010
# Epoch 18/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.5000 - loss: 0.9611
# Epoch 18: val_loss improved from 1.09515 to 1.09449, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step - accuracy: 0.5000 - loss: 0.9798 - val_accuracy: 0.4375 - val_loss: 1.0945 - learning_rate: 0.0010
# Epoch 19/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.7794 - loss: 0.7014
# Epoch 19: val_loss improved from 1.09449 to 1.09405, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step - accuracy: 0.7059 - loss: 0.7833 - val_accuracy: 0.3750 - val_loss: 1.0940 - learning_rate: 0.0010
# Epoch 20/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4697 - loss: 1.0665
# Epoch 20: val_loss did not improve from 1.09405
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4700 - loss: 1.0621 - val_accuracy: 0.4375 - val_loss: 1.0951 - learning_rate: 0.0010

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

faixa_epochs = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(faixa_epochs, acc, label='Treino Accuracy')
plt.plot(faixa_epochs, val_acc, label='Validacao Accuracy')

plt.legend(loc='lower right')
plt.title('Treino and Validacao Accuracy')

plt.subplot(1, 2, 2)
plt.plot(faixa_epochs, loss, label='Treino Loss')
plt.plot(faixa_epochs, val_loss, label='Validacao Loss')
plt.legend(loc='upper right')
plt.title('Treino and Validacao Loss')
plt.show()

# %%
import numpy as np
def plot_one_img(img,score):
    # Plotar a imagem
    plt.figure(figsize=(8, 8))
    plt.imshow(img)
    plt.title(f'Classificada como {nomes_classes[np.argmax(score)]}\ncom uma precisão de {100 * np.max(score):.2f}%')
    plt.axis('off')
    plt.show()
    
def classificar_for_wpp(path_img):
    img = tf.keras.utils.load_img(
        path_img, target_size=(img_height, img_width)
    )
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])
    # plot_one_img(img,score)
    print(
        f"classificada como {nomes_classes[np.argmax(score)]} \ncom uma accuracy de {100 * np.max(score):.2f} %."
    )
classificar_for_wpp(r'C:\Users\User\Desktop\modelo_classifier\imagens_para_teste\escassa (31).jpg')
classificar_for_wpp(r'C:\Users\User\Desktop\modelo_classifier\imagens_para_teste\mediana (16).jpg')
classificar_for_wpp(r'C:\Users\User\Desktop\modelo_classifier\imagens_para_teste\uniforme (13).jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# classificada como Uniforme
# com uma accuracy de 33.83 %.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# classificada como Uniforme
# com uma accuracy de 33.97 %.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# classificada como Escassa
# com uma accuracy de 33.85 %.
